# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## read and describe the metadata

# %%
fpn_csv = './cluster_images.csv'
data = pd.read_csv(fpn_csv, encoding='ISO-8859-1')

# %%
# get column names
list(data)
# Out:
# ['s_no',
#  'artist',
#  'title',
#  'art_movement',
#  'museum_venue',
#  'country_of_origin',
#  'has_text',
#  'primary_medium',
#  'medium',
#  'work_size',
#  'date',
#  'representation',
#  'representation_semi',
#  'kinetic',
#  'map',
#  'map2',
#  'spatial_dimension',
#  'spatial_dimension2',
#  'pl',
#  'si',
#  'va',
#  'te',
#  'co',
#  'or',
#  'sh',
#  'reflection',
#  'po',
#  'li',
#  'ar',
#  'notes']

# %%
data.head()
# Out:
#    s_no              artist                         title art_movement  \
# 0     2  Giorgio de Chirico  The Uncertainty of the Poet    surrealism
# 1     3    Giovanni Anselmo                     Direction  arte povera
# 2     4        Milton Avery                   Yellow Sky     modernism
# 3     5       Gillian Avery                  Distillation  abstraction
# 4     6   Joseph (Jef) Banc          Pair-Bearing Matrix   abstraction
#
#   museum_venue country_of_origin  has_text primary_medium  \
# 0         Tate             Italy     False       painting
# 1         Tate             Italy     False      sculpture
# 2         Tate           America     False       painting
# 3         Tate                UK     False       painting
# 4         Tate            France     False       painting
#
#                                         medium          work_size  \
# 0                      painting, oil on canvas        106 x 94 cm
# 1             sculpture, fabric, glass & metal  24 x 420 x 335 cm
# 2                      painting, oil on canvas       156 x 184 cm
# 3  painting, oil, household paint on hardboard       213 x 152 cm
# 4              painting, mixed media on canvas         73 x 60 cm
#
#                          ...                         va  te  co  or  sh  \
# 0                        ...                          3   0   0   4   3
# 1                        ...                          1   3   0   3   2
# 2                        ...                          2   4   4   2   4
# 3                        ...                          1   2   0   2   4
# 4                        ...                          1   4   1   0   4
#
#    reflection  po  li  ar                                              notes
# 0       False   0   0   5  distorted perspective, shadow, signification o...
# 1       False   0   0   5  hard to understand the viewpoint, sense of for...
# 2       False   0   0   5  flatish, textured shapes & specific colors-lin...
# 3       False   0   0   5  shapes, layers, paint handlng/texture, orienta...
# 4       False   0   0   5  ambiguity through abstraction, odd shape, v te...
#
# [5 rows x 30 columns]

# %% [markdown]
# ## create a subset of the columns you will use to fit KMeans
#
# Here, I am **arbitrarily** choosing the seven [visual variables defined by Bertin](https://infovis-wiki.net/wiki/Visual_Variables). Variable descriptions [here](https://github.com/visualizedata/ml/blob/master/ML_assignment_3/option_2/contents-of-cluster_images.csv).
#
# You should choose the columns that you decide will best define the clusters. You may need to make transformations on existing variables.

# %%
X = data[['pl', 'si','va', 'representation', 'te', 'ar', 'or', 'sh']]

# %%
X.head()
# Out:
#    pl  si  va  representation  te  ar  or  sh
# 0   2   2   3            True   0   5   4   3
# 1   4   3   1            True   3   5   3   2
# 2   3   0   2            True   4   5   2   4
# 3   4   3   1           False   2   5   2   4
# 4   1   0   1           False   4   5   0   4

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## plot inertia scores by number of clusters

# %%
# first attempt at fitting K means to view change in Inertia

# container to store inertia scores over iterations
distortions = []

# fit KMeans iteratively to begin to assess the appropriate number of clusters
for i in range(1, 101):
    km = KMeans(n_clusters=i)
    km.fit(X)
    distortions.append(km.inertia_)
    
vizualize change in inertia
plt.plot(range(1, 101), distortions, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## create silhouette plots to assess various specifications for `n_clusters` in `KMeans`

# %%
# modify this list to include the numbers of clusters you want to see
# I have *arbitrarily* chosen these values
range_n_clusters = [10, 20, 30, 40, 50]

# %%
# modified from: http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import random

for n_clusters in range_n_clusters:
    # Create a subplot
    fig, (ax1) = plt.subplots(1, 1)
    fig.set_size_inches(9, 17)

    # The silhouette coefficient can range from -1, 1 but in this example all lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    silhouette_avg = silhouette_score(X, cluster_labels)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        # select a random color for this cluster
        r = lambda: random.randint(0,255)
        color = '#%02X%02X%02X' % (r(),r(),r())
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

    plt.show()
# Out:
# For n_clusters = 10 The average silhouette_score is : 0.18421171774719278
# For n_clusters = 20 The average silhouette_score is : 0.17971402551141707
# For n_clusters = 30 The average silhouette_score is : 0.1873448029974104
# For n_clusters = 40 The average silhouette_score is : 0.18643267190864143
# For n_clusters = 50 The average silhouette_score is : 0.18870344589576127

# %% [markdown]
# ## final fit
#
# After you have decided which features to include and the number of clusters you want, fit your final KMeans model. I have **arbitrarily** chosen 5.

# %%
# set the number of clusters in the final model
my_n_clusters = 50

# %%
km = KMeans(n_clusters=my_n_clusters, n_init=10)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=50, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ## look at results
#
# The key to knowing if you have chosen the right features and clusters: looking at the images in each cluster and deciding whether they seem to belong together. You could extend this starter code to display the images in this notebook, or you may decide to use Python to write an html file/files to view the images by cluster.

# %%
for i in range(0, max(km.labels_)+1):
    print(" ")
    print("* * * * * * * * * * * * * * * * * * * * * * * * * * * * * * ")
    print("Images in cluster: " + str(i))
    print("* * * * * * * * * * * * * * * * * * * * * * * * * * * * * * ")
    for j in range(0, len(km.labels_)):
        if km.labels_[j] == i:
            print(str(j+2) + '_small.jpg')
# Out:
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 0
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 14_small.jpg
# 19_small.jpg
# 26_small.jpg
# 83_small.jpg
# 117_small.jpg
# 174_small.jpg
# 185_small.jpg
# 213_small.jpg
# 234_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 1
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 55_small.jpg
# 136_small.jpg
# 155_small.jpg
# 173_small.jpg
# 196_small.jpg
# 243_small.jpg
# 313_small.jpg
# 347_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 2
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 11_small.jpg
# 16_small.jpg
# 69_small.jpg
# 88_small.jpg
# 197_small.jpg
# 225_small.jpg
# 284_small.jpg
# 315_small.jpg
# 325_small.jpg
# 383_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 3
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 32_small.jpg
# 34_small.jpg
# 79_small.jpg
# 121_small.jpg
# 164_small.jpg
# 186_small.jpg
# 223_small.jpg
# 226_small.jpg
# 232_small.jpg
# 238_small.jpg
# 251_small.jpg
# 259_small.jpg
# 319_small.jpg
# 328_small.jpg
# 330_small.jpg
# 349_small.jpg
# 365_small.jpg
# 389_small.jpg
# 399_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 4
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 39_small.jpg
# 53_small.jpg
# 57_small.jpg
# 124_small.jpg
# 181_small.jpg
# 261_small.jpg
# 293_small.jpg
# 355_small.jpg
# 357_small.jpg
# 370_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 5
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 172_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 6
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 60_small.jpg
# 131_small.jpg
# 175_small.jpg
# 199_small.jpg
# 250_small.jpg
# 257_small.jpg
# 260_small.jpg
# 331_small.jpg
# 342_small.jpg
# 344_small.jpg
# 360_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 7
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 75_small.jpg
# 219_small.jpg
# 241_small.jpg
# 317_small.jpg
# 402_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 8
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 68_small.jpg
# 73_small.jpg
# 91_small.jpg
# 97_small.jpg
# 129_small.jpg
# 133_small.jpg
# 299_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 9
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 43_small.jpg
# 113_small.jpg
# 128_small.jpg
# 290_small.jpg
# 346_small.jpg
# 386_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 10
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 3_small.jpg
# 111_small.jpg
# 140_small.jpg
# 146_small.jpg
# 163_small.jpg
# 335_small.jpg
# 356_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 11
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 10_small.jpg
# 61_small.jpg
# 145_small.jpg
# 154_small.jpg
# 177_small.jpg
# 305_small.jpg
# 341_small.jpg
# 345_small.jpg
# 353_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster:
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 41_small.jpg
# 42_small.jpg
# 44_small.jpg
# 58_small.jpg
# 64_small.jpg
# 66_small.jpg
# 85_small.jpg
# 86_small.jpg
# 92_small.jpg
# 112_small.jpg
# 118_small.jpg
# 189_small.jpg
# 210_small.jpg
# 247_small.jpg
# 263_small.jpg
# 334_small.jpg
# 359_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 34
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 103_small.jpg
# 169_small.jpg
# 379_small.jpg
# 400_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 35
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 7_small.jpg
# 47_small.jpg
# 161_small.jpg
# 249_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 36
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 12_small.jpg
# 151_small.jpg
# 180_small.jpg
# 183_small.jpg
# 202_small.jpg
# 220_small.jpg
# 395_small.jpg
# 401_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 37
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 37_small.jpg
# 102_small.jpg
# 253_small.jpg
# 276_small.jpg
# 279_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 38
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 13_small.jpg
# 15_small.jpg
# 72_small.jpg
# 93_small.jpg
# 122_small.jpg
# 244_small.jpg
# 262_small.jpg
# 280_small.jpg
# 303_small.jpg
# 312_small.jpg
# 348_small.jpg
# 361_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 39
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 52_small.jpg
# 59_small.jpg
# 77_small.jpg
# 80_small.jpg
# 162_small.jpg
# 170_small.jpg
# 229_small.jpg
# 295_small.jpg
# 296_small.jpg
# 306_small.jpg
# 333_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 40
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 98_small.jpg
# 150_small.jpg
# 203_small.jpg
# 204_small.jpg
# 212_small.jpg
# 268_small.jpg
# 273_small.jpg
# 275_small.jpg
# 294_small.jpg
# 368_small.jpg
# 372_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 41
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 27_small.jpg
# 283_small.jpg
# 301_small.jpg
# 387_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 42
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 54_small.jpg
# 96_small.jpg
# 157_small.jpg
# 304_small.jpg
# 352_small.jpg
# 371_small.jpg
# 394_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 43
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 67_small.jpg
# 87_small.jpg
# 160_small.jpg
# 278_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 44
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 38_small.jpg
# 40_small.jpg
# 50_small.jpg
# 82_small.jpg
# 116_small.jpg
# 127_small.jpg
# 132_small.jpg
# 148_small.jpg
# 153_small.jpg
# 209_small.jpg
# 248_small.jpg
# 255_small.jpg
# 256_small.jpg
# 264_small.jpg
# 266_small.jpg
# 291_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 45
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 179_small.jpg
# 298_small.jpg
# 332_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 46
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 17_small.jpg
# 25_small.jpg
# 114_small.jpg
# 143_small.jpg
# 211_small.jpg
# 215_small.jpg
# 265_small.jpg
# 337_small.jpg
# 340_small.jpg
# 397_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 47
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 31_small.jpg
# 62_small.jpg
# 78_small.jpg
# 90_small.jpg
# 135_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 48
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 158_small.jpg
# 206_small.jpg
# 214_small.jpg
# 391_small.jpg
#
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# Images in cluster: 49
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# 30_small.jpg
# 125_small.jpg
# 141_small.jpg
# 176_small.jpg
# 191_small.jpg
# 198_small.jpg
# 240_small.jpg
# 267_small.jpg
# 285_small.jpg
# 375_small.jpg
# 376_small.jpg
# 384_small.jpg
# 390_small.jpg

# %%
#import os
import tensorflow.keras as keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.models import Model

# %%
import glob
import random

imagefiles = glob.glob('./img_small/**/*.jpg', recursive=True)
# imagefiles.extend(glob.glob('./fashion/**/*.png'))
# imagefiles.extend(glob.glob('./fashion/**/*.jpeg'))
random.shuffle(imagefiles)
imagefiles = imagefiles[:450]
print(imagefiles)
# Out:
